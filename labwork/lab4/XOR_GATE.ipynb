# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

#weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
#bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



#multiply1=tf.add(tf.matmul(x,weights),bias)
#z=tf.nn.sigmoid(multiply1)


Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name="Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name="Theta2")
Bias1 = tf.Variable(tf.zeros([2]), name="Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name="Bias2")
A2 = tf.sigmoid(tf.matmul(x, Theta1) + Bias1)
z = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)
print(tf.shape(A2))    
cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[0]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(100000):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration = ",i,"cost= ",res)
    print ("Validating output for XOR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# Tensor("Shape:0", shape=(2,), dtype=int32)
# iteration =  0 cost=  0.733111
# iteration =  1000 cost=  0.69489
# iteration =  2000 cost=  0.694382
# iteration =  3000 cost=  0.693995
# iteration =  4000 cost=  0.693677
# iteration =  5000 cost=  0.693407
# iteration =  6000 cost=  0.693169
# iteration =  7000 cost=  0.692953
# iteration =  8000 cost=  0.692748
# iteration =  9000 cost=  0.692548
# iteration =  10000 cost=  0.692345
# iteration =  11000 cost=  0.692132
# iteration =  12000 cost=  0.691902
# iteration =  13000 cost=  0.691647
# iteration =  14000 cost=  0.691357
# iteration =  15000 cost=  0.691021
# iteration =  16000 cost=  0.690625
# iteration =  17000 cost=  0.690153
# iteration =  18000 cost=  0.689581
# iteration =  19000 cost=  0.688884
# iteration =  20000 cost=  0.688025
# iteration =  21000 cost=  0.68696
# iteration =  22000 cost=  0.685631
# iteration =  23000 cost=  0.683966
# iteration =  24000 cost=  0.681874
# iteration =  25000 cost=  0.679246
# iteration =  26000 cost=  0.675949
# iteration =  27000 cost=  0.671835
# iteration =  28000 cost=  0.666744
# iteration =  29000 cost=  0.660518
# iteration =  30000 cost=  0.653018
# iteration =  31000 cost=  0.644143
# iteration =  32000 cost=  0.633833
# iteration =  33000 cost=  0.622057
# iteration =  34000 cost=  0.608769
# iteration =  35000 cost=  0.593828
# iteration =  36000 cost=  0.576877
# iteration =  37000 cost=  0.557201
# iteration =  38000 cost=  0.533642
# iteration =  39000 cost=  0.50474
# iteration =  40000 cost=  0.469346
# iteration =  41000 cost=  0.427603
# iteration =  42000 cost=  0.381622
# iteration =  43000 cost=  0.334983
# iteration =  44000 cost=  0.291213
# iteration =  45000 cost=  0.252532
# iteration =  46000 cost=  0.219651
# iteration =  47000 cost=  0.192268
# iteration =  48000 cost=  0.169634
# iteration =  49000 cost=  0.150915
# iteration =  50000 cost=  0.135352
# iteration =  51000 cost=  0.122315
# iteration =  52000 cost=  0.1113
# iteration =  53000 cost=  0.101914
# iteration =  54000 cost=  0.0938469
# iteration =  55000 cost=  0.086858
# iteration =  56000 cost=  0.0807575
# iteration =  57000 cost=  0.0753955
# iteration =  58000 cost=  0.0706523
# iteration =  59000 cost=  0.0664314
# iteration =  60000 cost=  0.0626547
# iteration =  61000 cost=  0.0592586
# iteration =  62000 cost=  0.0561906
# iteration =  63000 cost=  0.053407
# iteration =  64000 cost=  0.0508714
# iteration =  65000 cost=  0.0485531
# iteration =  66000 cost=  0.0464263
# iteration =  67000 cost=  0.044469
# iteration =  68000 cost=  0.0426622
# iteration =  69000 cost=  0.0409899
# iteration =  70000 cost=  0.0394379
# iteration =  71000 cost=  0.0379937
# iteration =  72000 cost=  0.0366473
# iteration =  73000 cost=  0.0353889
# iteration =  74000 cost=  0.034211
# iteration =  75000 cost=  0.0331056
# iteration =  76000 cost=  0.0320666
# iteration =  77000 cost=  0.0310882
# iteration =  78000 cost=  0.0301656
# iteration =  79000 cost=  0.0292945
# iteration =  80000 cost=  0.0284704
# iteration =  81000 cost=  0.0276895
# iteration =  82000 cost=  0.026949
# iteration =  83000 cost=  0.0262461
# iteration =  84000 cost=  0.0255774
# iteration =  85000 cost=  0.0249406
# iteration =  86000 cost=  0.024334
# iteration =  87000 cost=  0.0237553
# iteration =  88000 cost=  0.0232028
# iteration =  89000 cost=  0.0226745
# iteration =  90000 cost=  0.0221689
# iteration =  91000 cost=  0.0216845
# iteration =  92000 cost=  0.0212201
# iteration =  93000 cost=  0.0207746
# iteration =  94000 cost=  0.0203478
# iteration =  95000 cost=  0.0199374
# iteration =  96000 cost=  0.0195424
# iteration =  97000 cost=  0.0191619
# iteration =  98000 cost=  0.0187968
# iteration =  99000 cost=  0.018444
# Validating output for XOR GATE
# [[ 0.01757976]
#  [ 0.9834435 ]
#  [ 0.97728765]
#  [ 0.01489873]]
